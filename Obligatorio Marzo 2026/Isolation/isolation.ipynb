# %%
from isolation_env import IsolationEnv
from input_agent import InputAgent
from random_agent import RandomAgent
from stratagem import Stratagem
from play import play_vs_other_agent
from minimax_agent import MinimaxAgent
from expectimax_agent import ExpectimaxAgent

# %%
env = IsolationEnv()
input_agent = InputAgent()
env.action_space
# Out:
# Discrete(9)

# %% [markdown]
# Input Agents

# %%
play_vs_other_agent(env, agent1=input_agent, agent2=input_agent)
# Out:
# Please insert a valid action.
# Please insert a valid action.
# Please insert a valid action.
# Please insert a valid action.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 play_vs_other_agent(env, agent1=input_agent, agent2=input_agent)
#
# File c:\Users\Usuario\Desktop\Obligatorio-IA-Abzaradel-Olaso-282958-281981-\Obligatorio Marzo 2026\Isolation\play.py:8, in play_vs_other_agent(env, agent1, agent2, render)
#       6 if render: env.render()
#       7 action = agent1.next_action(obs)
# ----> 8 obs, _, done, winner, _ = env.step(action)
#      10 if render: env.render()
#      11 if not done:
#
# File c:\Users\Usuario\Desktop\Obligatorio-IA-Abzaradel-Olaso-282958-281981-\Obligatorio Marzo 2026\Isolation\isolation_env.py:26, in IsolationEnv.step(self, action)
#      24     self.next_player()
#      25 else:
# ---> 26     raise ValueError("Invalid action")
#      28 done, winner = self.is_done()
#      29 return self.grid, self.get_reward(), done, winner, {}
#
# ValueError: Invalid action

# %% [markdown]
# Random Agents

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=RandomAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 | R   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 | R   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 | X   |     |     | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 | X   |     |     | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 | X   |     |     | X   |
# +-----+-----+-----+-----+-----+
# |   3 | R   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 | X   |     |     | X   |
# +-----+-----+-----+-----+-----+
# |   3 | R   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 | X   | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# Player 2 WON

# %% [markdown]
# Random Agent vs Stratagem

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=Stratagem(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | R   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | R   | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | R   | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | X   | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# Player 2 WON

# %% [markdown]
# Random Agent vs Minimax

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=MinimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     | B   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | R   |     | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | X   | X   | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# Player 2 WON

# %% [markdown]
# Cambiando el orden de Random vs Minimax

# %%
play_vs_other_agent(env, agent1=MinimaxAgent(1), agent2=RandomAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     | R   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   | R   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | B   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     | R   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     | R   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | R   | X   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | R   | X   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | R   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | B   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | R   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | B   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | R   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# Player 1 WON

# %% [markdown]
# Stratagem vs Minimax

# %%
play_vs_other_agent(env, agent1=Stratagem(1), agent2=MinimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     | R   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | B   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     | R   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | B   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     | R   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     | R   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 | B   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 | B   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# Player 1 WON

# %% [markdown]
# Cambiando el orden de Stratagem vs Minimax

# %%
play_vs_other_agent(env, agent1=MinimaxAgent(1), agent2=Stratagem(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 | B   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | R   |     | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | R   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | R   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | X   | R   |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | X   | R   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   3 |     | X   | R   | X   |
# +-----+-----+-----+-----+-----+
# Player 1 WON

# %% [markdown]
# Random vs Expectimax

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=ExpectimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     | R   |
# +-----+-----+-----+-----+-----+
# |   1 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | B   | R   |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 | X   |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | B   | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     | R   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 | X   |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     | X   |     | R   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | B   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   |     | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     | R   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | B   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     | R   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   |     | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | B   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | X   |     | R   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   |     | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | X   | B   | R   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | X   | B   | R   | X   |
# +-----+-----+-----+-----+-----+
# |   3 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# Player 1 WON

# %% [markdown]
# Expectimax vs Random

# %%
play_vs_other_agent(env, agent1=ExpectimaxAgent(1), agent2=RandomAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | B   |     | R   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   |     | R   |
# +-----+-----+-----+-----+-----+
# |   1 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 |     | B   |     | R   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   |     | R   |
# +-----+-----+-----+-----+-----+
# |   2 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | R   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 | X   |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | R   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | X   | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 | X   | B   |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 | X   | X   | R   |     |
# +-----+-----+-----+-----+-----+
# |   3 | X   | B   | X   |     |
# +-----+-----+-----+-----+-----+
# Player 2 WON

# %% [markdown]
# Strategem vs Expectimax

# %%
play_vs_other_agent(env, agent1=Stratagem(1), agent2=ExpectimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | R   | B   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | X   | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | R   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   | B   |
# +-----+-----+-----+-----+-----+
# |   1 |     |     | X   | X   |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | R   |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# Player 2 WON

# %% [markdown]
# Expectimax vs Stratagem

# %%
play_vs_other_agent(env, agent1=ExpectimaxAgent(1), agent2=Stratagem(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   |     | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 |     | R   | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | R   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | B   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | X   | R   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     | B   |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# Player 1 WON

# %% [markdown]
# Minimax vs Expectimax

# %%
play_vs_other_agent(env, agent1=MinimaxAgent(1), agent2=ExpectimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   1 | B   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | B   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | R   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | B   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | R   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | R   | X   | X   | X   |
# +-----+-----+-----+-----+-----+
# |   1 | X   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | B   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# Player 1 WON

# %% [markdown]
# Expectimax vs Minimax

# %%
play_vs_other_agent(env, agent1=ExpectimaxAgent(1), agent2=MinimaxAgent(2), render=True)
# Out:
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# |   1 | B   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | B   | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   |     |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# +-----+-----+-----+-----+-----+
# |     | 0   | 1   | 2   | 3   |
# +=====+=====+=====+=====+=====+
# |   0 | B   | X   | X   |     |
# +-----+-----+-----+-----+-----+
# |   1 | X   | R   |     |     |
# +-----+-----+-----+-----+-----+
# |   2 |     | X   |     |     |
# +-----+-----+-----+-----+-----+
# |   3 |     |     |     |     |
# +-----+-----+-----+-----+-----+
# Player 2 WON

# %% [markdown]
# Pruebas Generales

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import itertools
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 from IPython.display import display
#
# ModuleNotFoundError: No module named 'pandas'
